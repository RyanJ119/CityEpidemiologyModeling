# %% [markdown]
# # SEIR-Campus Examples
#
# This file illustrates some of the examples from the corresponding paper on the SEIR-Courses package.  Many of the function here call on classes inside the SEIR-Courses package.  We encourage you to look inside the package and explore!
#
# The data file that comes in the examples, publicdata.data, is based on course network published by Weeden and Cornwell at https://osf.io/6kuet/.  Course names, as well as some student demographic information, and varsity athlete ids have been assigned randomly and are not accurate representations of student demographics and varsity athletics at Cornell University.

# %%
from datetime import datetime, timedelta
from PySeirCampus import *
import os

# %% [markdown]
# ### Load the data for the simulations.

# %%
holiday_list = [(2020, 10, 14)]
holidays = set(datetime(*h) for h in holiday_list)
#semester = Semester('publicdata.data', holidays)

# %%
generated_meetings_folder = "C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events"
meeting_files = os.listdir(generated_meetings_folder) 

#Filtering only the data files.
meetings_files = [generated_meetings_folder + "/" + f for f in meeting_files if f.endswith(".data")] 
meetings_files
# Out:
# ['C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/E.data',
#  'C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/I.data',
#  'C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/meetings0.data',
#  'C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/meetings1.data',
#  'C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/meetings2.data',
#  'C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/R.data',
#  'C:/Users/Administrator.DESKTOP-D3SVMI5/Documents/Jupyter_Notebook/09282022_SEIR/SEIR-Campus-master/events/S.data']

# %%
semester = Semester(meetings_files[4], holidays)

# %% [markdown]
# ### Run a first simulation!

# %%
parameters = Parameters(reps = 5)
parameters.initial_exposure = 1
parameters.info()
# Out:
# verbose = False
# rate = 4e-05
# daily_spontaneous_prob = 0
# contact_tracing = DefaultContactTracing(no action)
# intervention_policy = DefaultInterventionPolicy(no intervention)
# infection_duration = VariedResponse(contagious: 0.2857, recovery: 0.2222, symptoms: 0.5, asympt ratio: 0.75)
# quarantine_length = 14
# preclass_interaction_time = 0
# initial_exposure = 1
# preprocess = <function Parameters.__init__.<locals>.<lambda> at 0x0000022DA2147E50>
# repetitions = 5
# start_date = 2020-09-02 00:00:00
# end_date = 2020-11-13 00:00:00
# vaccine_benefit_self = 0.9
# vaccine_benefit_others = 0.5

# %%
run_repetitions(semester, parameters)
# Out:
# Running 5 repetitions.
# Initial exposed: 1
# Average final exposure count is 5555.0
# Sample Standard deviation is: 0.0
# Quarantine: max 0.0 , avg 0.0

# %%
parameters = Parameters(reps = 30)
parameters.initial_exposure = 1
parameters.info()
# Out:
# verbose = False
# rate = 4e-05
# daily_spontaneous_prob = 0
# contact_tracing = DefaultContactTracing(no action)
# intervention_policy = DefaultInterventionPolicy(no intervention)
# infection_duration = VariedResponse(contagious: 0.2857, recovery: 0.2222, symptoms: 0.5, asympt ratio: 0.75)
# quarantine_length = 14
# preclass_interaction_time = 0
# initial_exposure = 1
# preprocess = <function Parameters.__init__.<locals>.<lambda> at 0x000002BEBE628550>
# repetitions = 30
# start_date = 2020-09-02 00:00:00
# end_date = 2020-11-13 00:00:00
# vaccine_benefit_self = 0.9
# vaccine_benefit_others = 0.5

# %%
run_repetitions(semester, parameters)
# Out:
# Running 30 repetitions.
# Initial exposed: 1
# Average final exposure count is 149999.96666666667
# Sample Standard deviation is: 0.18257418583505536
# Quarantine: max 0.0 , avg 0.0

# %%
semester = Semester(meetings_files[0], holidays)
parameters = Parameters(reps = 30)
parameters.initial_exposure = 1
parameters.info()
# Out:
# verbose = False
# rate = 4e-05
# daily_spontaneous_prob = 0
# contact_tracing = DefaultContactTracing(no action)
# intervention_policy = DefaultInterventionPolicy(no intervention)
# infection_duration = VariedResponse(contagious: 0.2857, recovery: 0.2222, symptoms: 0.5, asympt ratio: 0.75)
# quarantine_length = 14
# preclass_interaction_time = 0
# initial_exposure = 1
# preprocess = <function Parameters.__init__.<locals>.<lambda> at 0x0000017BE04BF670>
# repetitions = 30
# start_date = 2020-09-02 00:00:00
# end_date = 2020-11-13 00:00:00
# vaccine_benefit_self = 0.9
# vaccine_benefit_others = 0.5

# %%
run_repetitions(semester, parameters)
# Out:
# Running 30 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.96666666667
# Sample Standard deviation is: 0.18257418583505536
# Quarantine: max 0.0 , avg 0.0

# %%
run_repetitions(semester, parameters)
# Out:
# Running 30 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.933333333334
# Sample Standard deviation is: 0.2537081317024624
# Quarantine: max 0.0 , avg 0.0

# %%
run_repetitions(semester, parameters)
# Out:
# Running 30 repetitions.
# Initial exposed: 1
# Average final exposure count is 49975.0
# Sample Standard deviation is: 0.0
# Quarantine: max 0.0 , avg 0.0

# %%
# One rep to figure out the trace of spread

# %%
semester = Semester(meetings_files[0], holidays)
parameters = Parameters(reps = 100)
parameters.initial_exposure = 1
parameters.info()
# Out:
# verbose = False
# rate = 4e-05
# daily_spontaneous_prob = 0
# contact_tracing = DefaultContactTracing(no action)
# intervention_policy = DefaultInterventionPolicy(no intervention)
# infection_duration = VariedResponse(contagious: 0.2857, recovery: 0.2222, symptoms: 0.5, asympt ratio: 0.75)
# quarantine_length = 14
# preclass_interaction_time = 0
# initial_exposure = 1
# preprocess = <function Parameters.__init__.<locals>.<lambda> at 0x0000017BDD425310>
# repetitions = 100
# start_date = 2020-09-02 00:00:00
# end_date = 2020-11-13 00:00:00
# vaccine_benefit_self = 0.9
# vaccine_benefit_others = 0.5

# %%
run_repetitions(semester, parameters)
# Out:
# Running 100 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.99
# Sample Standard deviation is: 0.09999999999999999
# Quarantine: max 0.0 , avg 0.0

# %%
run_repetitions(semester, parameters)
# Out:
# Running 100 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.97
# Sample Standard deviation is: 0.1714466079977653
# Quarantine: max 0.0 , avg 0.0

# %%
run_repetitions(semester, parameters)
# Out:
# Running 100 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.94
# Sample Standard deviation is: 0.6000000000000001
# Quarantine: max 0.0 , avg 0.0

# %%
semester = Semester(meetings_files[0], holidays)
parameters = Parameters(reps = 30)
parameters.initial_exposure = 1
parameters.info()
# Out:
# verbose = False
# rate = 4e-05
# daily_spontaneous_prob = 0
# contact_tracing = DefaultContactTracing(no action)
# intervention_policy = DefaultInterventionPolicy(no intervention)
# infection_duration = VariedResponse(contagious: 0.2857, recovery: 0.2222, symptoms: 0.5, asympt ratio: 0.75)
# quarantine_length = 14
# preclass_interaction_time = 0
# initial_exposure = 1
# preprocess = <function Parameters.__init__.<locals>.<lambda> at 0x00000290E19D30D0>
# repetitions = 30
# start_date = 2020-09-02 00:00:00
# end_date = 2020-11-13 00:00:00
# vaccine_benefit_self = 0.9
# vaccine_benefit_others = 0.5

# %%
run_repetitions(semester, parameters)
# Out:
# Running 30 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.96666666667
# Sample Standard deviation is: 0.18257418583505536
# Quarantine: max 0.0 , avg 0.0

# %%
run_repetitions(semester, parameters)
# Out:
# Running 30 repetitions.
# Initial exposed: 1
# Average final exposure count is 49974.96666666667
# Sample Standard deviation is: 0.18257418583505536
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# ### Example when no one self reports/shows symptoms.

# %%
parameters = Parameters(reps = 10)
#parameters.infection_duration = BasicInfectionDuration(1 / 3.5, 1 / 4.5)
parameters.infection_duration = VariedResponse(1 / 3.5, 1 / 4.5, 1 / 2, 0.75)
run_repetitions(semester, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 11965.0
# Sample Standard deviation is: 161.16933813711452
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# ### Example of infection testing

# %%
parameters = Parameters(reps = 10)
parameters.intervention_policy = IpWeekdayTesting(semester)
run_repetitions(semester, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 10.5
# Sample Standard deviation is: 0.97182531580755
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# ### Example with Contact Tracing and Quarantines

# %%
parameters = Parameters(reps = 10)
parameters.contact_tracing = BasicContactTracing(14)
run_repetitions(semester, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 9.9
# Sample Standard deviation is: 1.7919573407620817
# Quarantine: max 22.0 , avg 6.026027397260275

# %% [markdown]
# ### Example with hybrid classes

# %%
semester_alt_hybrid = make_alternate_hybrid(semester)
parameters = Parameters(reps = 10)
run_repetitions(semester_alt_hybrid, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 11.4
# Sample Standard deviation is: 0.9660917830792959
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# ### Building social groups.
#
# For proper randomization, these groups should be recreated for each simulation repetition using the preprocess feature in the parameters.  However, this can add significant time to the computations.
#
# First, consider generating random clusters of students each day.

# %%
settings = ClusterSettings(
        start_date = min(semester.meeting_dates), end_date = max(semester.meeting_dates),
        weekday_group_count = 280, weekday_group_size = 10, weekday_group_time = 120,
        weekend_group_count = 210, weekend_group_size = 20, weekend_group_time = 180)

def groups_random(semester):
    clusters = make_randomized_clusters(semester.students, settings)
    return make_from_clusters(semester, clusters)

parameters = Parameters(reps = 10)
parameters.preprocess = groups_random
run_repetitions(semester, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 15.8
# Sample Standard deviation is: 2.485513584307633
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# Next, consider when some students form pairs.

# %%
def pairing(semester):
    clusters, _ = make_social_groups_pairs(semester, 0.25, interaction_time = 1200, 
                                           weighted=False)
    return make_from_clusters(semester, clusters)

parameters = Parameters(reps = 10)
parameters.preprocess = pairing
run_repetitions(semester, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 11.9
# Sample Standard deviation is: 1.1972189997378648
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# Next, we consider social interactions among varsity athletes.  In the first case, we assume that new social clusters are formed within teams each day.

# %%
def groups_varsity(semester):
        clusters, processed = make_social_groups_varsity(semester, 6, 240, 6, 240)
        return make_from_clusters(semester, clusters)

parameters = Parameters(reps = 10)
parameters.preprocess = groups_varsity
run_repetitions(semester, parameters)
# Out:
# Running 10 repetitions.
# Initial exposed: 10
# Average final exposure count is 12.5
# Sample Standard deviation is: 1.2692955176439846
# Quarantine: max 0.0 , avg 0.0

# %% [markdown]
# Finally, we consider varsity teams again but assume that the athletes keep socialization within the same cluster of people each day.

# %%
def groups_static_varsity(semester):
        clusters, processed = make_social_groups_varsity_static(semester, 6, 240)
        return make_from_clusters(semester, clusters)

parameters = Parameters(reps = 10)
parameters.preprocess = groups_static_varsity
run_repetitions(semester, parameters)

# %% [markdown]
# ## Other ways to explore
#
# Here are some other ideas for how to play around with the simulations!
#
# Try changing the infection rate.  Here we retry the first simulation, but with 10% lower infection rate.

# %%
def test_infection_sensitivity(semester, delta):
    parameters = Parameters(reps = 10)
    parameters.rate *= (1 + delta)
    run_repetitions(semester, parameters)

test_infection_sensitivity(semester, -0.10)

# %% [markdown]
# Suppose that the percentage of students that are asymptomatic is now 50% instead of 75%.

# %%
def test_asymptomatic(semester, ratio):
    parameters = Parameters(reps = 10)
    parameters.infection_duration = VariedResponse(1 / 3.5, 1 / 4.5, 1 / 2, ratio)
    run_repetitions(semester, parameters)

test_asymptomatic(semester, 0.5)

# %% [markdown]
# Eliminate external sources of exposure.

# %%
def test_outsideclass(semester, increase_factor):
    parameters = Parameters(reps = 10)
    parameters.daily_spontaneous_prob *= increase_factor
    run_repetitions(semester, parameters)
    
test_outsideclass(semester, 0)

# %% [markdown]
# Change the number of initial infections from 10 to 0 (reasonable if arrival testing is conducted).

# %%
def test_initialconditions(semester, initial_change):
    parameters = Parameters(reps = 10)
    parameters.initial_exposure *= initial_change
    run_repetitions(semester, parameters)
    
test_initialconditions(semester, 0)

# %% [markdown]
# Test students once per week, on Sunday.

# %%
def test_test_onceperweek(semester, weekday = 0):
    parameters = Parameters(reps = 10)
    parameters.intervention_policy = IpWeeklyTesting(semester, weekday = weekday)
    run_repetitions(semester, parameters)

test_test_onceperweek(semester, weekday = 6)

# %% [markdown]
# Test students one per week, on Monday.

# %%
test_test_onceperweek(semester, weekday = 0)
